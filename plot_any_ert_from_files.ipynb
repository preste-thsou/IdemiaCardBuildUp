# %%
import numpy as np
import matplotlib.pyplot as plt 
from visualization import plot_ERT
from problem.utils import GetDataFromFileFUN

# %% [markdown]
# # Run time empirical cumulative density function

# %% [markdown]
# # Get data from file

# %%
smpso_st1_ert_data = GetDataFromFileFUN('result/test_MHv5d_100k_corrected/SMPSO_1/ERT_data.SMPSO.mainproblem')
smpso_st2_ert_data = GetDataFromFileFUN('result/test_MHv5s_100k_corrected/SMPSO_1/ERT_data.SMPSO.mainproblem')
# new data ..

# %% [markdown]
# # Build list of fronts and front's names

# %%
ert_data= [
         smpso_st1_ert_data,
         smpso_st2_ert_data,
        # new front's data ...
         ] 
ert_data_names = [
            'SMPSO:  ERT : 100k : st 1', 
            'SMPSO:  ERT : 100k : st 2',
            # new front's names ...
           ]

# %% [markdown]
# # Plot it

# %%
plot_ERT(ert_data, ert_data_names, folder = '', show = True)
